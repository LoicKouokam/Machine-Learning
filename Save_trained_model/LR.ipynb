# %%
import numpy  as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df= pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area, df.price, color="red", marker="+")
plt.xlabel("area(sqr ft)")
plt.ylabel("price(US$)")
# Out:
# Text(0, 0.5, 'price(US$)')

# %%
### X should have 2 D shape 
area=df.drop('price',axis='columns')
area.shape

# %%
reg=linear_model.LinearRegression()
reg.fit(area, df.price )
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\loic\miniforge3\envs\ML\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
### Predict many value at once 
d=pd.read_csv("areas.csv")
d.shape
# Out:
# (13, 1)

# %%
p=reg.predict(d)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
d["prices"]=p

# %%
d.to_csv("prediction.csv", index=False)

# %%
plt.scatter(df.area, df.price, color="red", marker="+")
plt.plot(df.area, reg.predict(area), color="blue")
plt.xlabel("area(sqr ft)")
plt.ylabel("price(US$)")
# Out:
# Text(0, 0.5, 'price(US$)')
